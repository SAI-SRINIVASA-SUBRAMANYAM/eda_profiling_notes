# %% [raw]
# requirements

# %%
pip install autoviz
# Out:
# ...
#
# ...
#   Using cached typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# ...
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=3ad47c1f1238fe65daaf93b7aadb1de4414f7cab7774a6e4304bd96b5fd6ee21
#   Stored in directory: c:\users\subra\appdata\local\pip\cache\wheels\b0\4a\c8\9c580a0ea94dea641b8023456a1b178a7e4509d992224ed4aa
# Successfully built emoji
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.4.1
#     Uninstalling bokeh-2.4.1:
#       Successfully uninstalled bokeh-2.4.1
# ...

# %% [raw]
# Keynotes:
# Focuses on visualizing the relationship of data, with the help of different types of plots
#
# Reports:
# Overview of the dataset.
# Pairwise scatter plot of continous variables.
# Distribution of categorical variables
# Heatmaps of continous variables
# Average numerical varaible by each categorical variable

# %%
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Classs

# %%
df = pd.read_csv('https://raw.githubusercontent.com/SAI-SRINIVASA-SUBRAMANYAM/eda_profiling_notes/main/Visadataset.csv')

# %%
cat_cols = ['continent','education_of_employee', 'has_job_experience', 'requires_job_training', 'yr_of_estab', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
df[cat_cols] = df[cat_cols].astype('category')

# %%
avc = AutoViz_Class()

# %%
avc.AutoViz(filename="", dfte=df, chart_format="server")
# Out:
# Shape of your Data Set loaded: (25480, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# <style type="text/css">
# #T_41465_row0_col0, #T_41465_row0_col4, #T_41465_row1_col0, #T_41465_row1_col4, #T_41465_row8_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# ...
